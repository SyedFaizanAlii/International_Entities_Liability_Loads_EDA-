# %% [markdown]
# <div class="author-card" style="border-radius: 10px; overflow: hidden; box-shadow: 0px 0px 20px rgba(0, 0, 0, 0.2); transition: transform 0.3s ease;">
#     <div style="background-color: #FFA500;; padding: 20px; text-align: center;">
#         <h3 style="color: #7E3517; font-size:240%;font-weight: bold;">ABOUT THE AUTHOR</h3>
#     </div>
#     <div style="padding: 20px;">
#         <h1 align="center">
#     <img src="https://readme-typing-svg.herokuapp.com/?font=Righteous&size=35&center=true&vCenter=true&width=500&height=70&duration=4000&lines=Hi+There!+👋;+I'm+Syed+Faizan+Ali!;" />
# </h1>
#         <p style="text-align: center;">
#               A passionate computer science student with a solid foundation in C++, Java, and Python. 📊 Developing skills in <strong>data analysis<strong>, <strong>visualization<strong>, and <strong>statistical modeling<strong>. Diving into the fascinating world of AI and machine learning.
#         </p>
#         <div style="text-align: center; margin-bottom: 10px;">
#             <img src="https://media.licdn.com/dms/image/D4E03AQEOzUzCyHUVBw/profile-displayphoto-shrink_200_200/0/1714810772941?e=1721865600&v=beta&t=_c2yT6BRtDGVgGmEI_MabPsFyChp008qJjVmN2Md1hc" alt="Profile Picture" style="width: 100px; height: 100px; border-radius: 50%; border: 2px solid white;">
#         </div>
#         <p style="text-align: center;">
#             You can find more about me on my <a href="https://github.com/SyedFaizanAlii" target="_blank" style="color: #2196F3; text-decoration: none;">GitHub</a> and <a href="https://www.linkedin.com/in/syed-faizan-ali-70b164306/" target="_blank" style="color: #2196F3; text-decoration: none;">LinkedIn</a>.<br>
#             Feel free to connect and reach out for any collaboration or queries!
#         </p>
#     </div>
# </div>
# <style>
#     .author-card:hover {
#         transform: translateY(-5px);
#     }
# </style>

# %% [markdown]
# ---

# %% [markdown]
# <div class="step-title" style="transition: transform 0.3s ease;">
#     <a id="Import"></a>
#     <h1 style="background-color: #FFA500; font-family: calibri; color: #7E3517; font-weight: bold; font-size: 440%; text-align: center; border-radius: 15px 50px;">Step 1 | Importing Libraries</h1>
# </div>
#
# <style>
#     .step-title:hover {
#         transform: translateY(-5px);
#     }
# </style>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from colorama import Fore, Style, init;
# Import necessary libraries
from IPython.display import display, HTML



# Paellete
palette = ['#D7A9E3FF', '#8BBEE8FF', '#A8D5BAFF']
color_palette = sns.color_palette(palette)
# Remove Warnings
import warnings 
warnings.filterwarnings("ignore")
# Set the option to display all columns
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---

# %% [markdown]
# <div class="step-title" style="transition: transform 0.3s ease;">
#     <a id="Import"></a>
#     <h1 style="background-color: #FFA500; font-family: calibri; color: #7E3517; font-weight: bold; font-size: 440%; text-align: center; border-radius: 15px 50px;">Step 2 | Read Dataset</h1>
# </div>
#
# <style>
#     .step-title:hover {
#         transform: translateY(-5px);
#     }
# </style>

# %%
df = pd.read_csv('International Entities with Largest liability Loads.csv')
df
# Out:
#       Rank                         Company Stock Symbol  \
# 0        1                            ICBC      1398.HK
# 1        2      Agricultural Bank of China    601288.SS
# 2        3         China Construction Bank    601939.SS
# 3        4                   Bank of China    601988.SS
# 4        5                      Fannie Mae        FNMAL
# ...    ...                             ...          ...
# 8390  8391   Gulf Medical Projects Company      GMPC.AE
# 8391  8392  Gulf Pharmaceutical Industries   JULPHAR.AE
# 8392  8393              Eshraq Investments    ESHRAQ.AE
# 8393  8394    Al Wathba National Insurance     AWNIC.AE
# 8394  8395          Gryphon Digital Mining         GRYP
#
#       total liabilities (USD) in Trillion  price (USD)        company origin
# 0                            6.055620e+12     0.552394                 China
# 1                            5.423330e+12     0.606850                 China
# ...

# %% [markdown]
# ---

# %% [markdown]
# <div class="step-title" style="transition: transform 0.3s ease;">
#     <a id="Import"></a>
#     <h1 style="background-color: #FFA500; font-family: calibri; color: #7E3517; font-weight: bold; font-size: 440%; text-align: center; border-radius: 15px 50px;">Step 3 | Data Overview</h1>
# </div>
#
# <style>
#     .step-title:hover {
#         transform: translateY(-5px);
#     }
# </style>

# %%
# Text Color
def PrintColor(text: str, color=Fore.CYAN, style=Style.BRIGHT):
    "Prints color outputs using colorama using a text F-string"
    print(style + color + text + Style.RESET_ALL)

# Text For Main Heading
def print_blue_large(text):
    PrintColor(text, Fore.RED + Style.BRIGHT)

# Main Heading
def print_boxed_blue_heading(text):
    length = len(text) + 4
    print(f"\n{Style.BRIGHT}{Fore.RED}{'='*length}{Style.RESET_ALL}")
    print(f"{Style.BRIGHT}{Fore.YELLOW}| {text} |{Style.RESET_ALL}")
    print(f"{Style.BRIGHT}{Fore.RED}{'='*length}{Style.RESET_ALL}")

# Function to Overview Data
def data_overview(df):

    # Display head of the training dataset nicely
    print_boxed_blue_heading("The Head Of The Dataset is:")
    display(HTML(df.head(5).to_html(index=False).replace('<table border="1" class="dataframe">', '<table style="border: 2px solid blue;">')))

    print('\n')

    # Shapes of Train and Test
    print_boxed_blue_heading("Shape Information:")
    PrintColor(f"The Shape Of The Data is {df.shape} || No of Rows is : {df.shape[0]} and Columns is {df.shape[1]}", Fore.CYAN)
    print('\n')

    # Info of Both Datasets
    print_boxed_blue_heading("Dataset Information:")
    PrintColor(f"\nThe Info Of The Dataset", Fore.CYAN)
    df.info()

    # Describe Both
    print_boxed_blue_heading("Numerical Summary:")
    PrintColor(f"\nThe Numerical Summary is", Fore.CYAN)
    display(df.describe().style.set_caption("Data Summary").set_table_styles([{'selector': 'caption', 'props': [('color', 'blue')]}]))

    # Null Values in Data
    print_boxed_blue_heading("Null Values:")
    PrintColor("\nNull Values in Data", Fore.CYAN)
    print(df.isnull().sum())
    print('\n')

    # Duplicates Values in Data
    print_boxed_blue_heading("Duplicate Values:")
    PrintColor("\nDuplicates Values in Data", Fore.CYAN)
    print(df.duplicated().sum())

# %%
data_overview(df)
# Out:
# ...
# | The Head Of The Dataset is: |
# ...
# <table style="border: 2px solid blue;">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Rank</th>
#       <th>Company</th>
#       <th>Stock Symbol</th>
#       <th>total liabilities (USD) in Trillion</th>
#       <th>price (USD)</th>
#       <th>company origin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>ICBC</td>
#       <td>1398.HK</td>
#       <td>6.055620e+12</td>
#       <td>0.552394</td>
#       <td>China</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Agricultural Bank of China</td>
#       <td>601288.SS</td>
#       <td>5.423330e+12</td>
#       <td>0.606850</td>
#       <td>China</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>China Construction Bank</td>
#       <td>601939.SS</td>
#       <td>5.050590e+12</td>
#       <td>0.986478</td>
#       <td>China</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>Bank of China</td>
#       <td>601988.SS</td>
# ...

# %% [markdown]
# <span style="font-size:150%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid red; padding: 10px; border-radius: 10px; display: inline-block;">
#     So the data have 0 Duplicates values and have some null values So remove these null values
# </span>

# %%
# Drop the values
df = df.dropna()

# %% [markdown]
# ---

# %% [markdown]
# <div class="step-title" style="transition: transform 0.3s ease;">
#     <a id="Import"></a>
#     <h1 style="background-color: #FFA500; font-family: calibri; color: #7E3517; font-weight: bold; font-size: 440%; text-align: center; border-radius: 15px 50px;">Step 4| Data Preprocessing</h1>
# </div>
#
# <style>
#     .step-title:hover {
#         transform: translateY(-5px);
#     }
# </style>

# %%
df
# Out:
#       Rank                     Company Stock Symbol  \
# 0        1                        ICBC      1398.HK
# 1        2  Agricultural Bank of China    601288.SS
# 2        3     China Construction Bank    601939.SS
# 3        4               Bank of China    601988.SS
# 4        5                  Fannie Mae        FNMAL
# ...    ...                         ...          ...
# 8207  8208              Asset Entities         ASST
# 8208  8209                 PunkPirates       PUN.WA
# 8209  8210        Aurora Energy Metals       1AE.AX
# 8210  8211            Unusual Machines         UMAC
# 8211  8212                    NeoVolta         NEOV
#
#       total liabilities (USD) in Trillion  price (USD) company origin
# 0                            6.055620e+12     0.552394          China
# 1                            5.423330e+12     0.606850          China
# 2                            5.050590e+12     0.986478          China
# ...

# %% [markdown]
# ---

# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size:100%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid red; padding: 10px; border-radius: 10px; display: inline-block;">
#          <span style="color: cyan; font-size: 250%;">Step 4.1</span> <span style="color: brown; font-size: 250%;"> |</span> <span style="color: #FFA500;font-size: 250%;">Transformation Data</span>
#     </span>
# </div>

# %% [markdown]
# <span style="font-size:150%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid red; padding: 10px; border-radius: 10px; display: inline-block;">
#      Here you can see the data coloumn <span style="color: yellow;">total liabilities (USD) in Trillion</span> have values in trillion so we transform these values in logarithmic transformation to minimize the data for easy to analysis
# </span>

# %%
# Function to transform of big values to easy analysis the data 
print_boxed_blue_heading("Transformation Of Data :")
def transform_values(df, column, method='log'):
    if method == 'log':
        # Apply logarithmic transformation
        df[column] = np.log10(df[column])
        transformed_column_name = f'log10_{column}'
        df.rename(columns={column: transformed_column_name}, inplace=True)
        print(f"{Fore.CYAN}{Style.BRIGHT}The Data Transform Successfully{Style.RESET_ALL}")
    return df

# Apply transformations
df = transform_values(df, 'total liabilities (USD) in Trillion')

# # Plotting function
# def plot_transformed_data(df, column):
#     plt.figure(figsize=(10, 6))
#     sns.histplot(df[column], kde=True, color='skyblue')
#     plt.title(f'Histogram of {column}')
#     plt.xlabel(column)
#     plt.ylabel('Frequency')
#     plt.show()

#     plt.figure(figsize=(10, 6))
#     sns.boxplot(df[column], color='lightgreen')
#     plt.title(f'Boxplot of {column}')
#     plt.xlabel(column)
#     plt.show()


# # plot_transformed_data(df, 'log10_total liabilities (USD) in Trillion')
# Out:
# ...
# | Transformation Of Data : |
# ...
# The Data Transform Successfully

# %% [markdown]
# ---

# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size:100%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid red; padding: 10px; border-radius: 10px; display: inline-block;">
#          <span style="color: cyan; font-size: 250%;">Step 4.2</span> <span style="color: brown; font-size: 250%;"> |</span> <span style="color: #FFA500;font-size: 250%;">Outliers Treatment</span>
#     </span>
# </div>

# %%
continuous_vars = ['log10_total liabilities (USD) in Trillion', 'price (USD)']
def data_outliers(df, continuous_vars):
    # Outliers in Data
    print_boxed_blue_heading("Outliers in Continuous Variables:")
    PrintColor("\nThe Total Outliers In The Dataset are:", Fore.CYAN)
    Q1 = df[continuous_vars].quantile(0.25)
    Q3 = df[continuous_vars].quantile(0.75)
    IQR = Q3 - Q1
    outliers = ((df[continuous_vars] < (Q1 - 1.5 * IQR)) | (df[continuous_vars] > (Q3 + 1.5 * IQR))).sum()
    outliers_df = pd.DataFrame(outliers, columns=['Outliers'])
    return outliers_df

# Example usage:
outliers_df = data_outliers(df, continuous_vars)
display(HTML(outliers_df.to_html().replace('<table border="1" class="dataframe">', '<table style="border: 2px solid blue;">')))
# Out:
# ...
# | Outliers in Continuous Variables: |
# ...
#
# The Total Outliers In The Dataset are:
# <table style="border: 2px solid blue;">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Outliers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>log10_total liabilities (USD) in Trillion</th>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>price (USD)</th>
#       <td>966</td>
#     </tr>
#   </tbody>
# </table>

# %%
def remove_outliers(df, continuous_vars):
    # df_clean = df.copy()
    print_boxed_blue_heading("Removal Of Outliers:")
    for var in continuous_vars:
        Q1 = df[var].quantile(0.25)
        Q3 = df[var].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[var] >= lower_bound) & (df[var] <= upper_bound)]
    print(f"{Fore.CYAN}{Style.BRIGHT}The Outliers Removed Successfully{Style.RESET_ALL}")
    return df

# Example usage:
df = remove_outliers(df, continuous_vars)
# Out:
# ...
# | Removal Of Outliers: |
# ...
# The Outliers Removed Successfully

# %% [markdown]
# ---

# %%
df.reset_index(drop=True, inplace=True)

# %%
df['Rank'] = df.index + 1

# %%
df
# Out:
#       Rank               Company Stock Symbol  \
# 0        1        Morgan Stanley           MS
# 1        2  Lloyds Banking Group          LYG
# 2        3                   ING          ING
# 3        4       Intesa Sanpaolo       ISP.MI
# 4        5   China Minsheng Bank    600016.SS
# ...    ...                   ...          ...
# 7154  7155            Freeze Tag         FRZT
# 7155  7156    New Pacific Metals         NEWP
# 7156  7157               Trulite         TRUL
# 7157  7158           Aura Energy       AURA.L
# 7158  7159       NVE Corporation         NVEC
#
#       log10_total liabilities (USD) in Trillion  price (USD)  company origin
# 0                                     12.038902    95.790000   United States
# 1                                     12.026039     2.650000  United Kingdom
# 2                                     12.022461    17.340000     Netherlands
# 3                                     11.997565     3.871440           Italy
# ...

# %% [markdown]
# ---

# %% [markdown]
# <div class="step-title" style="transition: transform 0.3s ease;">
#     <a id="Import"></a>
#     <h1 style="background-color: #FFA500; font-family: calibri; color: #7E3517; font-weight: bold; font-size: 440%; text-align: center; border-radius: 15px 50px;">Step 5 | EDA Analysis</h1>
# </div>
#
# <style>
#     .step-title:hover {
#         transform: translateY(-5px);
#     }
# </style>

# %% [markdown]
# ---

# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size:100%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid red; padding: 10px; border-radius: 10px; display: inline-block;">
#          <span style="color: cyan; font-size: 250%;">Heatmap</span> <span style="color: brown; font-size: 250%;"> |</span> <span style="color: #FFA500;font-size: 250%;">Numeric Columns For Correlation Matrix</span>
#     </span>
# </div>

# %%
# Select only numeric columns for correlation matrix
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
corr_matrix = df[numeric_columns].corr()

# Plotting the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size:100%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid red; padding: 10px; border-radius: 10px; display: inline-block;">
#          <span style="color: cyan; font-size: 250%;">Count Plot</span> <span style="color: brown; font-size: 250%;"> |</span> <span style="color: #FFA500;font-size: 250%;">Frequency of Top 10 Company Origins</span>
#     </span>
# </div>

# %%
# Find the top 10 most frequent company origins
top_10_origins = df['company origin'].value_counts().head(10).index

# Filter the dataset for the top 10 most frequent company origins
top_10_data = df[df['company origin'].isin(top_10_origins)]

# Define a color palette with different colors for each bar
colors = sns.color_palette("husl", len(top_10_origins))

# Plot the frequency of the top 10 most frequent company origins
plt.figure(figsize=(15, 8))
sns.countplot(y='company origin', data=top_10_data, order=top_10_data['company origin'].value_counts().index, palette=colors)
plt.title('Frequency of Top 10 Company Origins')
plt.xlabel('Count')
plt.ylabel('Company Origin')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size:100%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid red; padding: 10px; border-radius: 10px; display: inline-block;">
#          <span style="color: cyan; font-size: 250%;">Bar Plot</span> <span style="color: brown; font-size: 250%;"> |</span> <span style="color: #FFA500;font-size: 250%;">Comparative Analysis</span>
#     </span>
# </div>

# %%
# Filter the dataset for the top 10 most frequent company origins
top_10_data = df[df['company origin'].isin(top_10_origins)]
# Comparing average total liabilities by company origin
avg_liabilities_by_origin = top_10_data.groupby('company origin')['log10_total liabilities (USD) in Trillion'].mean().sort_values()
liabilities_colors = sns.color_palette("husl", len(avg_liabilities_by_origin))
plt.figure(figsize=(15,8))
avg_liabilities_by_origin.plot(kind='barh', color=liabilities_colors)
plt.title('Average Total Liabilities (USD) in Trillion by Company Origin')
plt.xlabel('Average Total Liabilities (USD) in Trillion')
plt.ylabel('Country')
plt.show()

# Comparing average stock price by company origin
avg_price_by_origin = top_10_data.groupby('company origin')['price (USD)'].mean().sort_values()
price_colors = sns.color_palette("Paired", len(avg_price_by_origin))
plt.figure(figsize=(15, 8))
avg_price_by_origin.plot(kind='barh', color=price_colors)
plt.title('Average Stock Price (USD) by Company Origin')
plt.xlabel('Average Stock Price (USD)')
plt.ylabel('Country')
plt.show()
# Top 10 companies by total liabilities
top_10_liabilities = df.nlargest(10, 'log10_total liabilities (USD) in Trillion')

# Plotting the top 10 companies by total liabilities
plt.figure(figsize=(14, 8))
sns.barplot(
    x='log10_total liabilities (USD) in Trillion', 
    y='Company', 
    data=top_10_liabilities, 
    palette='viridis'
)
plt.title('Top 10 Companies by Total Liabilities (USD) in Trillion')
plt.xlabel('Total Liabilities (USD) in Trillion')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size:100%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid red; padding: 10px; border-radius: 10px; display: inline-block;">
#          <span style="color: cyan; font-size: 250%;">Hist Plot:</span> <span style="color: brown; font-size: 250%;"> |</span> <span style="color: #FFA500;font-size: 250%;">Distribution of Liabilities and Prices</span>
#     </span>
# </div>

# %%
# Set up the visual style
sns.set(style="whitegrid")

# Plotting the distribution of 'total liabilities (USD) in Trillion'
plt.figure(figsize=(12, 6),)
sns.histplot(df['log10_total liabilities (USD) in Trillion'], bins=50, kde=True,color='RED')
plt.title('Distribution of Total Liabilities (USD) in Trillion')
plt.xlabel('Total Liabilities (USD) in Trillion')
plt.ylabel('Frequency')
plt.show()

# Plotting the distribution of 'price (USD)'
plt.figure(figsize=(12, 6))
sns.histplot(df['price (USD)'], bins=50, kde=True,color='RED')
plt.title('Distribution of Stock Price (USD)')
plt.xlabel('Stock Price (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size:100%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid red; padding: 10px; border-radius: 10px; display: inline-block;">
#          <span style="color: cyan; font-size: 250%;">Bar Plot</span> <span style="color: brown; font-size: 250%;"> |</span> <span style="color: #FFA500;font-size: 250%;">Total Liabilities by Top 10 Companies and Company Origin</span>
#     </span>
# </div>

# %%
# Filter the top 15 companies by total liabilities
top_15_companies = df.nlargest(10, 'log10_total liabilities (USD) in Trillion')

# Set the figure size
plt.figure(figsize=(14, 8))

# Create a bar plot of total liabilities by company, colored by company origin
sns.barplot(x='Company', y='log10_total liabilities (USD) in Trillion', hue='company origin', data=top_15_companies)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Set the title and labels
plt.title('Total Liabilities by Top 10 Companies and Company Origin')
plt.xlabel('Company')
plt.ylabel('Total Liabilities (in Trillion USD)')

# Display the legend
plt.legend(title='Company Origin')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1)) # to move the lagend outside the graph
# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size:100%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid red; padding: 10px; border-radius: 10px; display: inline-block;">
#          <span style="color: cyan; font-size: 250%;">Scatter Plot</span> <span style="color: brown; font-size: 250%;"> |</span> <span style="color: #FFA500;font-size: 250%;">Total Liabilities vs Stock Price</span>
#     </span>
# </div>

# %%
top_10_liabilities = df.nlargest(50, 'log10_total liabilities (USD) in Trillion')

plt.figure(figsize=(8, 6))
sns.scatterplot(x='log10_total liabilities (USD) in Trillion', y='price (USD)', data=top_10_liabilities, hue='company origin')

plt.legend(loc='upper left', bbox_to_anchor=(1, 1)) # to move the lagend outside the graph

plt.title('Scatter Plot of Total Liabilities vs Stock Price')
plt.xlabel('Total Liabilities (in Trillion USD)')
plt.ylabel('Stock Price (in USD)')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size:150%; font-family: calibri; background-color: lightbrown; color: CYAN; border: 2px solid #FFC107; padding: 10px; border-radius: 10px; display: inline-block;">
# <span style="color: RED;font-size:240%;">Observations:</span>
# <ul>
# <li>The United States has the highest stock price at 90 USD and highest Liabilities Almost 12.05 in Trillion USD .</li>
# <li>Brazil shows a broad range of stock prices relative to its total liabilities, with significant observations at 40 USD and 10 USD.</li>
# <li>The Netherlands has one of the higher stock prices at 60 USD for its total liabilities.</li>
# <li>The United States displays a wide range of stock prices, from 20 USD to 95 USD, indicating diverse financial conditions.</li>
# <li>China, Canada, and India show lower stock prices, generally around 15 USD to 20 USD.</li>
# <li>Countries like Australia, Spain, and France have mid-range stock prices between 25 USD and 30 USD.</li>
# <li>Japan and Finland show higher stock prices of 50 USD and 45 USD, respectively.</li>
# <li>Germany and Singapore have lower stock prices around 15 USD and 20 USD, respectively.</li>
# <li>Denmark and South Korea show moderate stock prices at 25 USD and 20 USD.</li>
# <li>Russia has a higher stock price of 45 USD for its total liabilities.</li>
# <li>The United Kingdom has the lowest stock price at 5 USD.</li>
# </ul>
# </span>

# %% [markdown]
# ---

# %% [markdown]
# <div
#         <h1 align="center">
#     <img src="https://readme-typing-svg.herokuapp.com/?font=Righteous&size=35&center=true&vCenter=true&width=500&height=70&color=F71352&duration=4000&lines=🙂+Happy+Ending!;" />
# </div>

# %% [markdown]
# ---
